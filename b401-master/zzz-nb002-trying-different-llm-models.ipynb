# %% [markdown]
# # Connect with alternative LLMs
# * Talk with Open Source LLMs like Llama3 and Mixtral.

# %% [markdown]
# ## Caveat
# * Keep in mind that the quality of Llama3 and Mixtral is still below the quality of OpenAI's ChatGPT.

# %% [markdown]
# ## Setup
# #### After you download the code from the github repository in your computer
# In terminal:
# * cd project_name
# * pyenv local 3.11.4
# * poetry install
# * poetry shell
#
# #### To open the notebook with Jupyter Notebooks
# In terminal:
# * jupyter lab
#
# Go to the folder of notebooks and open the right notebook.
#
# #### To see the code in Virtual Studio Code or your editor of choice.
# * open Virtual Studio Code or your editor of choice.
# * open the project-folder
# * open the 002-trying-different-llm-models.py file

# %% [markdown]
# ## Create your .env file
# * In the github repo we have included a file named .env.example
# * Rename that file to .env file and here is where you will add your confidential api keys. Remember to include:
# * OPENAI_API_KEY=your_openai_api_key
# * LANGCHAIN_TRACING_V2=true
# * LANGCHAIN_ENDPOINT=https://api.smith.langchain.com
# * LANGCHAIN_API_KEY=your_langchain_api_key
# * LANGCHAIN_PROJECT=your_project_name

# %% [markdown]
# We will call our LangSmith project **002-trying-different-llm-models**.

# %% [markdown]
# ## Track operations
# From now on, we can track the operations **and the cost** of this project from LangSmith:
# * [smith.langchain.com](https://smith.langchain.com)

# %% [markdown]
# ## Intro to Groq
# * Groq is an AI Startup company. **It is not the same as Grok, the LLM from Elon Musk**.
# * It has developed a new chip call LPU (Language Processing Unit) which is specificly design to run LLMs faster and cheaper.
# * It offers a Groq Cloud where you can try Open Source LLMs like Llama3 or Mixtral.
# * **It allows you to use Llama3 or Mixtral in your apps for free using a Groq API Key with some Rate Limits**.

# %% [markdown]
# ## How to get a free Groq API Key
# * Login into Groq Cloud: [https://console.groq.com/login](https://console.groq.com/login)
# * Once logged in, click on API Keys (left sidebar).
# * Create a new API Key.
# * Copy the API Key and paste it in your .env file.

# %% [markdown]
# ## How to install Groq in your project
# If you are using the pre-loaded poetry shell, you do not need to install the following package because it is already pre-loaded for you.
#
# LangChain has a module for it. We can install it the same way we install other LangChain modules, using PIP or (if we are working in a Poetry app) we can also install it using Poetry. Use one of the following options:
# * pip install langchain-groq
# * poetry add langchain-groq

# %% [markdown]
# ## How to use Groq in your LangChain or CrewAI project
# Very easy. Just add the following line at the top of your file:
# * from langchain_groq import ChatGroq
#
# And then, in the code, if you want to use Llama3:

# %%
# llm = ChatGroq(
#     model="llama3-70b-8192"
# )

# %% [markdown]
# Or if you want to use Mixtral:

# %%
# llm = ChatGroq(
#     model="mixtral-8x7b-32768"
# )

# %% [markdown]
# ## You can take a look at Groq Rate limits here
# * https://console.groq.com/settings/limits

# %% [markdown]
# ## Groq pricing for projects in Production
# * [Groq pricing](https://wow.groq.com/).

# %% [markdown]
# ## Let's give it a try!

# %% [markdown]
# If you are using the pre-loaded poetry shell, you do not need to install the following package because it is already pre-loaded for you:

# %%
#pip install langchain-groq

# %%
import os
from dotenv import load_dotenv, find_dotenv
_ = load_dotenv(find_dotenv())

# %%
from langchain_groq import ChatGroq

llamaChatModel = ChatGroq(
    model="llama3-70b-8192"
)

# %%
mistralChatModel = ChatGroq(
    model="mixtral-8x7b-32768"
)

# %%
messages = [
    ("system", "You are an historian expert in the Kennedy family."),
    ("human", "How many members of the family died tragically?"),
]

# %%
llamaResponse = llamaChatModel.invoke(messages)
# Out:
# ---------------------------------------------------------------------------
# BadRequestError                           Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 llamaResponse = llamaChatModel.invoke(messages)
#
# File ~\AppData\Local\pypoetry\Cache\virtualenvs\b401-1OsV-20c-py3.11\Lib\site-packages\langchain_core\language_models\chat_models.py:265, in BaseChatModel.invoke(self, input, config, stop, **kwargs)
#     254 def invoke(
#     255     self,
#     256     input: LanguageModelInput,
#    (...)
#     260     **kwargs: Any,
#     261 ) -> BaseMessage:
#     262     config = ensure_config(config)
#     263     return cast(
#     264         ChatGeneration,
# --> 265         self.generate_prompt(
#     266             [self._convert_input(input)],
#     267             stop=stop,
#     268             callbacks=config.get("callbacks"),
#     269             tags=config.get("tags"),
#     270             metadata=config.get("metadata"),
#     271             run_name=config.get("run_name"),
#     272             run_id=config.pop("run_id", None),
#     273             **kwargs,
#     274         ).generations[0][0],
#     275     ).message
#
# File ~\AppData\Local\pypoetry\Cache\virtualenvs\b401-1OsV-20c-py3.11\Lib\site-packages\langchain_core\language_models\chat_models.py:698, in BaseChatModel.generate_prompt(self, prompts, stop, callbacks, **kwargs)
#     690 def generate_prompt(
#     691     self,
#     692     prompts: List[PromptValue],
#    (...)
#     695     **kwargs: Any,
#     696 ) -> LLMResult:
#     697     prompt_messages = [p.to_messages() for p in prompts]
# --> 698     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#
# File ~\AppData\Local\pypoetry\Cache\virtualenvs\b401-1OsV-20c-py3.11\Lib\site-packages\langchain_core\language_models\chat_models.py:555, in BaseChatModel.generate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#     553         if run_managers:
#     554             run_managers[i].on_llm_error(e, response=LLMResult(generations=[]))
# --> 555         raise e
#     556 flattened_outputs = [
#     557     LLMResult(generations=[res.generations], llm_output=res.llm_output)  # type: ignore[list-item]
#     558     for res in results
#     559 ]
#     560 llm_output = self._combine_llm_outputs([res.llm_output for res in results])
#
# File ~\AppData\Local\pypoetry\Cache\virtualenvs\b401-1OsV-20c-py3.11\Lib\site-packages\langchain_core\language_models\chat_models.py:545, in BaseChatModel.generate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#     542 for i, m in enumerate(messages):
#     543     try:
#     544         results.append(
# --> 545             self._generate_with_cache(
#     546                 m,
#     547                 stop=stop,
#     548                 run_manager=run_managers[i] if run_managers else None,
#     549                 **kwargs,
#     550             )
#     551         )
#     552     except BaseException as e:
#     553         if run_managers:
#
# File ~\AppData\Local\pypoetry\Cache\virtualenvs\b401-1OsV-20c-py3.11\Lib\site-packages\langchain_core\language_models\chat_models.py:770, in BaseChatModel._generate_with_cache(self, messages, stop, run_manager, **kwargs)
#     768 else:
#     769     if inspect.signature(self._generate).parameters.get("run_manager"):
# --> 770         result = self._generate(
#     771             messages, stop=stop, run_manager=run_manager, **kwargs
#     772         )
#     773     else:
#     774         result = self._generate(messages, stop=stop, **kwargs)
#
# File ~\AppData\Local\pypoetry\Cache\virtualenvs\b401-1OsV-20c-py3.11\Lib\site-packages\langchain_groq\chat_models.py:472, in ChatGroq._generate(self, messages, stop, run_manager, **kwargs)
#     467 message_dicts, params = self._create_message_dicts(messages, stop)
#     468 params = {
#     469     **params,
#     470     **kwargs,
#     471 }
# --> 472 response = self.client.create(messages=message_dicts, **params)
#     473 return self._create_chat_result(response)
#
# File ~\AppData\Local\pypoetry\Cache\virtualenvs\b401-1OsV-20c-py3.11\Lib\site-packages\groq\resources\chat\completions.py:289, in Completions.create(self, messages, model, frequency_penalty, function_call, functions, logit_bias, logprobs, max_tokens, n, parallel_tool_calls, presence_penalty, response_format, seed, stop, stream, temperature, tool_choice, tools, top_logprobs, top_p, user, extra_headers, extra_query, extra_body, timeout)
#     148 def create(
#     149     self,
#     150     *,
#    (...)
#     177     timeout: float | httpx.Timeout | None | NotGiven = NOT_GIVEN,
#     178 ) -> ChatCompletion | Stream[ChatCompletionChunk]:
#     179     """
#     180     Creates a model response for the given chat conversation.
#     181
#    (...)
#     287       timeout: Override the client-level default timeout for this request, in seconds
#     288     """
# --> 289     return self._post(
#     290         "/openai/v1/chat/completions",
#     291         body=maybe_transform(
#     292             {
#     293                 "messages": messages,
#     294                 "model": model,
#     295                 "frequency_penalty": frequency_penalty,
#     296                 "function_call": function_call,
#     297                 "functions": functions,
#     298                 "logit_bias": logit_bias,
#     299                 "logprobs": logprobs,
#     300                 "max_tokens": max_tokens,
#     301                 "n": n,
#     302                 "parallel_tool_calls": parallel_tool_calls,
#     303                 "presence_penalty": presence_penalty,
#     304                 "response_format": response_format,
#     305                 "seed": seed,
#     306                 "stop": stop,
#     307                 "stream": stream,
#     308                 "temperature": temperature,
#     309                 "tool_choice": tool_choice,
#     310                 "tools": tools,
#     311                 "top_logprobs": top_logprobs,
#     312                 "top_p": top_p,
#     313                 "user": user,
#     314             },
#     315             completion_create_params.CompletionCreateParams,
#     316         ),
#     317         options=make_request_options(
#     318             extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#     319         ),
#     320         cast_to=ChatCompletion,
#     321         stream=stream or False,
#     322         stream_cls=Stream[ChatCompletionChunk],
#     323     )
#
# File ~\AppData\Local\pypoetry\Cache\virtualenvs\b401-1OsV-20c-py3.11\Lib\site-packages\groq\_base_client.py:1225, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1211 def post(
#    1212     self,
#    1213     path: str,
#    (...)
#    1220     stream_cls: type[_StreamT] | None = None,
#    1221 ) -> ResponseT | _StreamT:
#    1222     opts = FinalRequestOptions.construct(
#    1223         method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1224     )
# -> 1225     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File ~\AppData\Local\pypoetry\Cache\virtualenvs\b401-1OsV-20c-py3.11\Lib\site-packages\groq\_base_client.py:920, in SyncAPIClient.request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     911 def request(
#     912     self,
#     913     cast_to: Type[ResponseT],
#    (...)
#     918     stream_cls: type[_StreamT] | None = None,
#     919 ) -> ResponseT | _StreamT:
# --> 920     return self._request(
#     921         cast_to=cast_to,
#     922         options=options,
#     923         stream=stream,
#     924         stream_cls=stream_cls,
#     925         remaining_retries=remaining_retries,
#     926     )
#
# File ~\AppData\Local\pypoetry\Cache\virtualenvs\b401-1OsV-20c-py3.11\Lib\site-packages\groq\_base_client.py:1018, in SyncAPIClient._request(self, cast_to, options, remaining_retries, stream, stream_cls)
#    1015         err.response.read()
#    1017     log.debug("Re-raising status error")
# -> 1018     raise self._make_status_error_from_response(err.response) from None
#    1020 return self._process_response(
#    1021     cast_to=cast_to,
#    1022     options=options,
#    (...)
#    1025     stream_cls=stream_cls,
#    1026 )
#
# BadRequestError: Error code: 400 - {'error': {'message': 'The model `llama3-70b-8192` has been decommissioned and is no longer supported. Please refer to https://console.groq.com/docs/deprecations for a recommendation on which model to use instead.', 'type': 'invalid_request_error', 'code': 'model_decommissioned'}}

# %%
print(llamaResponse.content)
# Out:
# The Kennedy family has indeed been touched by tragedy numerous times throughout their history. It's a painful and poignant aspect of their story.
#
# To answer your question, a staggering number of Kennedy family members have met with tragic ends. Here's a brief rundown:
#
# 1. Joseph P. Kennedy Jr. (1915-1944): The eldest son of Joseph P. Kennedy Sr. and Rose Kennedy, Joseph Jr. was killed in action during World War II when his plane exploded on a secret mission over the English Channel.
