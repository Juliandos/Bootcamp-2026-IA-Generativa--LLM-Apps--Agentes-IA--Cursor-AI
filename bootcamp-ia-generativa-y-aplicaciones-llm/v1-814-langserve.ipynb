# %%
# !pip install python-dotenv
# Out:
# Requirement already satisfied: python-dotenv in c:\users\asus\desktop\rescate asus\yo\paginas web\udemy\bootcamp 2026 ia generativa, llm apps, agentes ia, cursor ai\venv\lib\site-packages (1.1.1)
# [notice] A new release of pip is available: 23.2.1 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import os
from dotenv import load_dotenv, find_dotenv
_ = load_dotenv(find_dotenv())
openai_api_key = os.environ["OPENAI_API_KEY"]

# %% [markdown]
# ## LangServe

# %% [markdown]
# Here's a server that deploys an OpenAI chat model and a chain that uses the OpenAI chat model to tell a joke about a topic.

# %%
# !pip install langserve
# Out:
# Collecting langserve
#   Obtaining dependency information for langserve from https://files.pythonhosted.org/packages/bd/f0/193c34bf61e1dee8bd637dbeddcc644c46d14e8b03068792ca60b1909bc1/langserve-0.3.2-py3-none-any.whl.metadata
#   Downloading langserve-0.3.2-py3-none-any.whl.metadata (40 kB)
#      ---------------------------------------- 0.0/40.3 kB ? eta -:--:--
#      -------------------- ------------------- 20.5/40.3 kB ? eta -:--:--
#      -------------------------------------- 40.3/40.3 kB 477.0 kB/s eta 0:00:00
# Requirement already satisfied: httpx<1.0,>=0.23.0 in c:\users\asus\desktop\rescate asus\yo\paginas web\udemy\bootcamp 2026 ia generativa, llm apps, agentes ia, cursor ai\venv\lib\site-packages (from langserve) (0.28.1)
# Collecting langchain-core<0.4,>=0.3 (from langserve)
#   Obtaining dependency information for langchain-core<0.4,>=0.3 from https://files.pythonhosted.org/packages/64/18/e7462ae0ce57caa9f6d5d975dca861e9a751e5ca253d60a809e0d833eac3/langchain_core-0.3.77-py3-none-any.whl.metadata
#   Downloading langchain_core-0.3.77-py3-none-any.whl.metadata (3.2 kB)
# Collecting orjson<4,>=2 (from langserve)
#   Obtaining dependency information for orjson<4,>=2 from https://files.pythonhosted.org/packages/09/60/db16c6f7a41dd8ac9fb651f66701ff2aeb499ad9ebc15853a26c7c152448/orjson-3.11.3-cp311-cp311-win_amd64.whl.metadata
#   Downloading orjson-3.11.3-cp311-cp311-win_amd64.whl.metadata (43 kB)
#      ---------------------------------------- 0.0/43.0 kB ? eta -:--:--
#      ---------------------------------------- 43.0/43.0 kB 1.0 MB/s eta 0:00:00
# Collecting pydantic<3.0,>=2.7 (from langserve)
#   Obtaining dependency information for pydantic<3.0,>=2.7 from https://files.pythonhosted.org/packages/3e/d3/108f2006987c58e76691d5ae5d200dd3e0f532cb4e5fa3560751c3a1feba/pydantic-2.11.9-py3-none-any.whl.metadata
#   Downloading pydantic-2.11.9-py3-none-any.whl.metadata (68 kB)
#      ---------------------------------------- 0.0/68.4 kB ? eta -:--:--
#      ----------------------------------- ---- 61.4/68.4 kB ? eta -:--:--
#      ---------------------------------------- 68.4/68.4 kB 1.9 MB/s eta 0:00:00
# Requirement already satisfied: anyio in c:\users\asus\desktop\rescate asus\yo\paginas web\udemy\bootcamp 2026 ia generativa, llm apps, agentes ia, cursor ai\venv\lib\site-packages (from httpx<1.0,>=0.23.0->langserve) (4.11.0)
# Requirement already satisfied: certifi in c:\users\asus\desktop\rescate asus\yo\paginas web\udemy\bootcamp 2026 ia generativa, llm apps, agentes ia, cursor ai\venv\lib\site-packages (from httpx<1.0,>=0.23.0->langserve) (2025.8.3)
# Requirement already satisfied: httpcore==1.* in c:\users\asus\desktop\rescate asus\yo\paginas web\udemy\bootcamp 2026 ia generativa, llm apps, agentes ia, cursor ai\venv\lib\site-packages (from httpx<1.0,>=0.23.0->langserve) (1.0.9)
# Requirement already satisfied: idna in c:\users\asus\desktop\rescate asus\yo\paginas web\udemy\bootcamp 2026 ia generativa, llm apps, agentes ia, cursor ai\venv\lib\site-packages (from httpx<1.0,>=0.23.0->langserve) (3.10)
# Requirement already satisfied: h11>=0.16 in c:\users\asus\desktop\rescate asus\yo\paginas web\udemy\bootcamp 2026 ia generativa, llm apps, agentes ia, cursor ai\venv\lib\site-packages (from httpcore==1.*->httpx<1.0,>=0.23.0->langserve) (0.16.0)
# Collecting langsmith<1.0.0,>=0.3.45 (from langchain-core<0.4,>=0.3->langserve)
#   Obtaining dependency information for langsmith<1.0.0,>=0.3.45 from https://files.pythonhosted.org/packages/72/80/ff33907e4d7b7dc56f8a592e404488baec9e79a1e5517dd19673a93597b7/langsmith-0.4.32-py3-none-any.whl.metadata
#   Downloading langsmith-0.4.32-py3-none-any.whl.metadata (14 kB)
# Collecting tenacity!=8.4.0,<10.0.0,>=8.1.0 (from langchain-core<0.4,>=0.3->langserve)
#   Obtaining dependency information for tenacity!=8.4.0,<10.0.0,>=8.1.0 from https://files.pythonhosted.org/packages/e5/30/643397144bfbfec6f6ef821f36f33e57d35946c44a2352d3c9f0ae847619/tenacity-9.1.2-py3-none-any.whl.metadata
#   Downloading tenacity-9.1.2-py3-none-any.whl.metadata (1.2 kB)
# Collecting jsonpatch<2.0.0,>=1.33.0 (from langchain-core<0.4,>=0.3->langserve)
#   Obtaining dependency information for jsonpatch<2.0.0,>=1.33.0 from https://files.pythonhosted.org/packages/73/07/02e16ed01e04a374e644b575638ec7987ae846d25ad97bcc9945a3ee4b0e/jsonpatch-1.33-py2.py3-none-any.whl.metadata
#   Downloading jsonpatch-1.33-py2.py3-none-any.whl.metadata (3.0 kB)
# Requirement already satisfied: PyYAML<7.0.0,>=5.3.0 in c:\users\asus\desktop\rescate asus\yo\paginas web\udemy\bootcamp 2026 ia generativa, llm apps, agentes ia, cursor ai\venv\lib\site-packages (from langchain-core<0.4,>=0.3->langserve) (6.0.3)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in c:\users\asus\desktop\rescate asus\yo\paginas web\udemy\bootcamp 2026 ia generativa, llm apps, agentes ia, cursor ai\venv\lib\site-packages (from langchain-core<0.4,>=0.3->langserve) (4.15.0)
# Requirement already satisfied: packaging<26.0.0,>=23.2.0 in c:\users\asus\desktop\rescate asus\yo\paginas web\udemy\bootcamp 2026 ia generativa, llm apps, agentes ia, cursor ai\venv\lib\site-packages (from langchain-core<0.4,>=0.3->langserve) (25.0)
# Collecting annotated-types>=0.6.0 (from pydantic<3.0,>=2.7->langserve)
#   Obtaining dependency information for annotated-types>=0.6.0 from https://files.pythonhosted.org/packages/78/b6/6307fbef88d9b5ee7421e68d78a9f162e0da4900bc5f5793f6d3d0e34fb8/annotated_types-0.7.0-py3-none-any.whl.metadata
#   Downloading annotated_types-0.7.0-py3-none-any.whl.metadata (15 kB)
# Collecting pydantic-core==2.33.2 (from pydantic<3.0,>=2.7->langserve)
#   Obtaining dependency information for pydantic-core==2.33.2 from https://files.pythonhosted.org/packages/fe/1b/25b7cccd4519c0b23c2dd636ad39d381abf113085ce4f7bec2b0dc755eb1/pydantic_core-2.33.2-cp311-cp311-win_amd64.whl.metadata
#   Downloading pydantic_core-2.33.2-cp311-cp311-win_amd64.whl.metadata (6.9 kB)
# Collecting typing-inspection>=0.4.0 (from pydantic<3.0,>=2.7->langserve)
#   Obtaining dependency information for typing-inspection>=0.4.0 from https://files.pythonhosted.org/packages/dc/9b/47798a6c91d8bdb567fe2698fe81e0c6b7cb7ef4d13da4114b41d239f65d/typing_inspection-0.4.2-py3-none-any.whl.metadata
#   Downloading typing_inspection-0.4.2-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\asus\desktop\rescate asus\yo\paginas web\udemy\bootcamp 2026 ia generativa, llm apps, agentes ia, cursor ai\venv\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<0.4,>=0.3->langserve) (3.0.0)
# Collecting requests-toolbelt>=1.0.0 (from langsmith<1.0.0,>=0.3.45->langchain-core<0.4,>=0.3->langserve)
#   Obtaining dependency information for requests-toolbelt>=1.0.0 from https://files.pythonhosted.org/packages/3f/51/d4db610ef29373b879047326cbf6fa98b6c1969d6f6dc423279de2b1be2c/requests_toolbelt-1.0.0-py2.py3-none-any.whl.metadata
#   Downloading requests_toolbelt-1.0.0-py2.py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: requests>=2.0.0 in c:\users\asus\desktop\rescate asus\yo\paginas web\udemy\bootcamp 2026 ia generativa, llm apps, agentes ia, cursor ai\venv\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<0.4,>=0.3->langserve) (2.32.5)
# Collecting zstandard>=0.23.0 (from langsmith<1.0.0,>=0.3.45->langchain-core<0.4,>=0.3->langserve)
#   Obtaining dependency information for zstandard>=0.23.0 from https://files.pythonhosted.org/packages/43/a3/c6155f5c1cce691cb80dfd38627046e50af3ee9ddc5d0b45b9b063bfb8c9/zstandard-0.25.0-cp311-cp311-win_amd64.whl.metadata
#   Downloading zstandard-0.25.0-cp311-cp311-win_amd64.whl.metadata (3.3 kB)
# Requirement already satisfied: sniffio>=1.1 in c:\users\asus\desktop\rescate asus\yo\paginas web\udemy\bootcamp 2026 ia generativa, llm apps, agentes ia, cursor ai\venv\lib\site-packages (from anyio->httpx<1.0,>=0.23.0->langserve) (1.3.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\asus\desktop\rescate asus\yo\paginas web\udemy\bootcamp 2026 ia generativa, llm apps, agentes ia, cursor ai\venv\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<0.4,>=0.3->langserve) (3.4.3)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\asus\desktop\rescate asus\yo\paginas web\udemy\bootcamp 2026 ia generativa, llm apps, agentes ia, cursor ai\venv\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<0.4,>=0.3->langserve) (2.5.0)
# Downloading langserve-0.3.2-py3-none-any.whl (1.2 MB)
#    ---------------------------------------- 0.0/1.2 MB ? eta -:--:--
#    ------------- -------------------------- 0.4/1.2 MB 8.3 MB/s eta 0:00:01
#    --------------------------------- ------ 1.0/1.2 MB 10.4 MB/s eta 0:00:01
#    ---------------------------------------  1.2/1.2 MB 10.6 MB/s eta 0:00:01
#    ---------------------------------------- 1.2/1.2 MB 6.8 MB/s eta 0:00:00
# Downloading langchain_core-0.3.77-py3-none-any.whl (449 kB)
#    ---------------------------------------- 0.0/449.5 kB ? eta -:--:--
#    --------------------------------------  440.3/449.5 kB 28.7 MB/s eta 0:00:01
#    --------------------------------------- 449.5/449.5 kB 14.2 MB/s eta 0:00:00
# Using cached orjson-3.11.3-cp311-cp311-win_amd64.whl (131 kB)
# Using cached pydantic-2.11.9-py3-none-any.whl (444 kB)
# Using cached pydantic_core-2.33.2-cp311-cp311-win_amd64.whl (2.0 MB)
# Using cached annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Using cached jsonpatch-1.33-py2.py3-none-any.whl (12 kB)
# Downloading langsmith-0.4.32-py3-none-any.whl (386 kB)
#    ---------------------------------------- 0.0/386.4 kB ? eta -:--:--
#    --------------------------------------  378.9/386.4 kB 23.0 MB/s eta 0:00:01
#    ---------------------------------------- 386.4/386.4 kB 8.0 MB/s eta 0:00:00
# Using cached tenacity-9.1.2-py3-none-any.whl (28 kB)
# Downloading typing_inspection-0.4.2-py3-none-any.whl (14 kB)
# Using cached requests_toolbelt-1.0.0-py2.py3-none-any.whl (54 kB)
# Using cached zstandard-0.25.0-cp311-cp311-win_amd64.whl (506 kB)
# Installing collected packages: zstandard, typing-inspection, tenacity, pydantic-core, orjson, jsonpatch, annotated-types, requests-toolbelt, pydantic, langsmith, langchain-core, langserve
# Successfully installed annotated-types-0.7.0 jsonpatch-1.33 langchain-core-0.3.77 langserve-0.3.2 langsmith-0.4.32 orjson-3.11.3 pydantic-2.11.9 pydantic-core-2.33.2 requests-toolbelt-1.0.0 tenacity-9.1.2 typing-inspection-0.4.2 zstandard-0.25.0
# [notice] A new release of pip is available: 23.2.1 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# !pip install sse_starlette
# Out:
# Collecting sse_starlette
#   Obtaining dependency information for sse_starlette from https://files.pythonhosted.org/packages/ef/10/c78f463b4ef22eef8491f218f692be838282cd65480f6e423d7730dfd1fb/sse_starlette-3.0.2-py3-none-any.whl.metadata
#   Downloading sse_starlette-3.0.2-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: anyio>=4.7.0 in c:\users\asus\desktop\rescate asus\yo\paginas web\udemy\bootcamp 2026 ia generativa, llm apps, agentes ia, cursor ai\venv\lib\site-packages (from sse_starlette) (4.11.0)
# Requirement already satisfied: idna>=2.8 in c:\users\asus\desktop\rescate asus\yo\paginas web\udemy\bootcamp 2026 ia generativa, llm apps, agentes ia, cursor ai\venv\lib\site-packages (from anyio>=4.7.0->sse_starlette) (3.10)
# Requirement already satisfied: sniffio>=1.1 in c:\users\asus\desktop\rescate asus\yo\paginas web\udemy\bootcamp 2026 ia generativa, llm apps, agentes ia, cursor ai\venv\lib\site-packages (from anyio>=4.7.0->sse_starlette) (1.3.1)
# Requirement already satisfied: typing_extensions>=4.5 in c:\users\asus\desktop\rescate asus\yo\paginas web\udemy\bootcamp 2026 ia generativa, llm apps, agentes ia, cursor ai\venv\lib\site-packages (from anyio>=4.7.0->sse_starlette) (4.15.0)
# Downloading sse_starlette-3.0.2-py3-none-any.whl (11 kB)
# Installing collected packages: sse_starlette
# Successfully installed sse_starlette-3.0.2
# [notice] A new release of pip is available: 23.2.1 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
#!/usr/bin/env python
from fastapi import FastAPI
from threading import Thread
from langchain.prompts import ChatPromptTemplate
from langchain_openai import ChatOpenAI
from langserve import add_routes


app = FastAPI(
  title="LangChain Server",
  version="1.0",
  description="A simple api server using Langchain's Runnable interfaces",
)

add_routes(
    app,
    ChatOpenAI(),
    path="/openai",
)

model = ChatOpenAI()

prompt = ChatPromptTemplate.from_template("tell me a joke about {topic}")

add_routes(
    app,
    prompt | model,
    path="/chain",
)

if __name__ == "__main__":
    import uvicorn

    @app.get("/")
    async def read_root():
        return {"Hello": "World"}

    # Function to run the Uvicorn server in a thread
    def run_server():
        uvicorn.run(app, host="127.0.0.1", port=8000, log_level="info")

    # Start the server in a separate thread
    thread = Thread(target=run_server)
    thread.start()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[16], line 2
#       1 #!/usr/bin/env python
# ----> 2 from fastapi import FastAPI
#       3 from threading import Thread
#       4 from langchain.prompts import ChatPromptTemplate
#
# ModuleNotFoundError: No module named 'fastapi'

# %% [markdown]
# ## Links

# %% [markdown]
# * Playground to check the app: [http://127.0.0.1:8000/](http://127.0.0.1:8000/)
# * API routes:
#     * [http://127.0.0.1:8000/openai](http://127.0.0.1:8000/openai)
#     * [http://127.0.0.1:8000/chain](http://127.0.0.1:8000/chain)
# * FastAPI API documentation: [http://127.0.0.1:8000/docs#/](http://127.0.0.1:8000/docs#/)
