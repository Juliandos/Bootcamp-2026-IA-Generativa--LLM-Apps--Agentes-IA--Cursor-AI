# %% [markdown]
# # Replit Documentation

# %% [markdown]
# ## What is Replit?
# * Replit is a coding workspace that runs in your browser.
# * It allows you to build and deploy apps.
# * Since it is a cloud tool, there is no configuration needed.
# * You can start from a template or install npm, python, etc. Replit takes care of the configuration for you.
# * Integrated:
#     * Secrets management.
#     * Databases.
#     * Deployment.
# * Replit Deployments make it easy to get any project (called Repl in Replit) and deploy it in the cloud.
# * With Replit you could even code and deploy from your phone.
# * With the new Gen AI features like the Replit Agent, Replit makes coding easier than ever even for people without coding experience.

# %% [markdown]
# ## Replit vs. Cursor
# * Cursor does not make it easy to deploy what you have coded. The Replit Agent does.
#     * Package management. Poetry.
#     * Dependencies.
#     * Installs.
#     * Connect with database (firebase, etc).
#     * Deployment.
#     * Connect to a custom domain.

# %% [markdown]
# ## Getting Started
# * [Replit Getting Started.](https://docs.replit.com/getting-started/intro-replit)

# %% [markdown]
# ## Introduction to Replit
# * Replit was born to make app development easier for everyone.
# * Replit is:
#     * IDE: code editor.
#     * In the browser.
#     * No configuration or setup required.
#     * Simple deployment.
#     * Hosting.
#     * Code collaboration
#     * Developer community.
#     * And more.
# * [Key terms.](https://docs.replit.com/additional-resources/key-terms)

# %% [markdown]
# ## Interesting links
# * [Replit Blog.](https://blog.replit.com/)
# * [Replit Guides.](https://blog.replit.com/replit-guides)
# * [Replit Community Hub.](https://replit.com/community-hub)
# * [Replit YouTube Channel.](https://www.youtube.com/@replit)
# * [Replit Tutorials and Learning](https://www.youtube.com/playlist?list=PLto9KpJAqHMT57MEWOZqrZogOIpofFQxs)
# * [Replit Free Online Course: 100 days of Python](https://replit.com/learn/100-days-of-python)

# %% [markdown]
# ## Replit Workspace
# * [Intro to the workspace.](https://docs.replit.com/replit-workspace/introduction-to-workspace)
# * [Configure a Repl.](https://docs.replit.com/replit-workspace/configuring-repl)
# * [Templates.](https://docs.replit.com/replit-workspace/templates)
# * [Dependency management.](https://docs.replit.com/replit-workspace/dependency-management)
# * [Workspace features.](https://docs.replit.com/category/workspace-features)
# * [SSH.](https://docs.replit.com/replit-workspace/ssh)
# * [Using Git on Replit.](https://docs.replit.com/category/using-git-on-replit)
# * [Replit Desktop App.](https://docs.replit.com/replit-workspace/desktop-app)
# * [Replit Mobile App.](https://docs.replit.com/replit-workspace/replit-mobile-app)
# * [Extensions.](https://docs.replit.com/replit-workspace/extensions)
# * [Ports.](https://docs.replit.com/replit-workspace/ports)
# * [Themes.](https://docs.replit.com/category/themes)
# * [Keyboard shortcuts.](https://docs.replit.com/replit-workspace/keyboard-shortcuts)

# %% [markdown]
# ## Other interesting notes not included in the Replit documentation yet
# * Besides git, there is a more simplistic **"history" feature to quick reverts**.
# * Besides turning a project into a template, you can also turn it into a **cover page**. Cover pages can be shared and forked in order to edit them without affecting the code of your original project.
# * The API keys you store in the **Secrets** tab are not shared when you share your project as a template or cover page, the only thing shared are the variable names. The new user will have to enter his own secrets in order to make the template or cover page to work.

# %% [markdown]
# ## Other interesting Replit liks
# * [Manage secret keys in Replit.](https://docs.replit.com/replit-workspace/workspace-features/secrets)
# * [Deployment in Replit.](https://docs.replit.com/cloud-services/deployments/about-deployments)
# * [Databases in Replit.](https://docs.replit.com/cloud-services/storage-and-databases/replit-database)
# * [Installing packages in Replit.](https://docs.replit.com/replit-workspace/dependency-management)
# * [Link to create a Repl now.](https://replit.com/new)
# * [Replit Support.](https://replit.com/~?supportform=true)

# %% [markdown]
# ## Replit Quickstarts: How to build...
# * **[Next.js App:](https://docs.replit.com/getting-started/Quickstarts/nextjs-app)** Steps to get your Next.js app up and running on Replit.
# * **[Flask App:](https://docs.replit.com/getting-started/Quickstarts/flask-app)** Steps to deploy your Flask app on Replit.
# * **[FastAPI Service:](https://docs.replit.com/getting-started/Quickstarts/fastapi-service)** Steps to deploy your FastAPI server on Replit.
# * **[Static Blog Site (Astro):](https://docs.replit.com/getting-started/Quickstarts/static-blog-astro)** The Astro starter kit template simplifies the process of building static websites. Steps to deploy Astro on Replit.
# * **[Webscrape and Slack Notification Bot:](https://docs.replit.com/getting-started/Quickstarts/webscrape-and-slack-notifications)** This guide will walk you through the steps to scrape HackerNews and send data to a given Slack channel of your choice.
# * **[AI Slack Channel Summarizer:](https://docs.replit.com/getting-started/Quickstarts/ai-slack-channel-summerizer)** This guide will walk you through the steps to set up a Slack bot that summarizes channels using GPT-4.
# * **[Google Sheets Integration:](https://docs.replit.com/getting-started/Quickstarts/google-sheets-integration)** This guide will walk you through the steps to pull data from Google Sheets so you can process it or serve it as a web application.
# * **[Discord Bot:](https://docs.replit.com/getting-started/Quickstarts/discord-bot)** This guide will help you set up a Discord bot in Python that tells jokes.

# %% [markdown]
# ## Intro to Replit Agent (also called Replit AI)
# * Replit Agent is still in experimental mode.
# * Good for simple projects and MVPs. For complex projects it will likely not work yet.

# %% [markdown]
# ## Recommended process with Replit Agent
# * Ask chatgpt to create a detailed prompt to develop you idea. For example: "From the following idea... create a detailed proposal (requirement specs and technical document) to ask a junior development to develop this project." The more specific (goal, logic, use case, languages, tools, platform, similar projects, etc), the better.
# * Enter the detailed prompt in the Replit Agent.
# * See initial proposal from Replit Agent.
# * Click on Approve Plan and Start.
# * Interact with the Replit Agent to improve the results.

# %% [markdown]
# ## Replit AI
# * [Getting started.](https://docs.replit.com/replitai/getting-started)
# * [Complete code.](https://docs.replit.com/replitai/complete-code)
# * [Replit AI chat.](https://docs.replit.com/replitai/replitai-chat)
# * [Explain code.](https://docs.replit.com/replitai/explain-code)
# * [Edit code.](https://docs.replit.com/replitai/edit-code)
# * [Generate code.](https://docs.replit.com/replitai/generate-code)
# * [Replit agent.](https://docs.replit.com/replitai/agent)
# * [Model farm.](https://docs.replit.com/category/model-farm)

# %% [markdown]
# ## Cloud Services
# * [Usage-based billing.](https://docs.replit.com/cloud-services/about-usage-based-billing)
# * [Replit deployments.](https://docs.replit.com/category/replit-deployments)
# * [Custom domains with deployments.](https://docs.replit.com/cloud-services/deployments/custom-domains)
# * [Storage and Database.](https://docs.replit.com/category/storage-and-databases)

# %% [markdown]
# ## Services Included in the Replit Core subscription
# * [Overview.](https://docs.replit.com/replit-core/replit-core)

# %% [markdown]
# ## Additional Resources
# * [Managing your Repls.](https://docs.replit.com/additional-resources/managing-repls)
# * [Replit FAQs.](https://docs.replit.com/faq/)
# * [Edit compute specification.](https://docs.replit.com/additional-resources/boosts)
# * [Private Repls.](https://docs.replit.com/additional-resources/private-repls)
# * [Sharing your Repl.](https://docs.replit.com/additional-resources/sharing-your-repl)
# * [Authenticating users with Replit Auth.](https://docs.replit.com/additional-resources/authenticating-users-repl-auth)
# * [Google authentication in python and flask.](https://docs.replit.com/additional-resources/google-auth-in-flask)
