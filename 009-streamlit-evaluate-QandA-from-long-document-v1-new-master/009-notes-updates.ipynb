# %% [markdown]
# # Streamlit Evaluate Q&A from Long Document - Modern Version
#
# A modernized version of the Streamlit RAG (Retrieval-Augmented Generation) evaluation application using the latest versions of Python 3.13.3, Poetry 2.1.4, Streamlit 1.49+, and LangChain 0.3+ modular architecture.
#
# ## Features
#
# - **RAG App Evaluation**: Test the quality of retrieval-augmented generation systems
# - **Document Upload**: Process .txt files for knowledge base creation
# - **Vector Database**: FAISS-based document embeddings and similarity search
# - **Question-Answer Evaluation**: Compare AI-generated answers against known correct answers
# - **Hallucination Detection**: Identify when AI produces incorrect or fabricated information
# - **Evaluation Chain**: Automated grading of answer quality and accuracy
# - **Modern dependency stack** with the most comprehensive LangChain integration
#
# ## Requirements
#
# - Python 3.13.3 or higher
# - Poetry 2.1.4 or higher
#
# ## Installation
#
# 1. Navigate to the project directory:
# ```bash
# cd 009-streamlit-evaluate-QandA-from-long-document-v1-new
# ```
#
# 2. Install dependencies:
# ```bash
# poetry-2.1.4 install
# ```
#
# ## Usage
#
# 1. Start the Streamlit application:
# ```bash
# poetry-2.1.4 run streamlit run main.py
# ```
#
# 2. Open your browser to the displayed URL (typically http://localhost:8501)
#
# 3. **Upload Document**: Upload a .txt file containing your knowledge base
#
# 4. **Enter Question**: Provide a question you've already fact-checked
#
# 5. **Provide Real Answer**: Enter the known correct answer to the question
#
# 6. **Enter API Key**: Provide your OpenAI API key in the form
#
# 7. **Submit**: Click Submit to evaluate the RAG system
#
# 8. **View Results**: See the comparison between AI answer and real answer with evaluation grade
#
# ## How RAG Evaluation Works
#
# ### 1. Document Processing
# - **Text Splitting**: Document is chunked into manageable pieces (1000 characters)
# - **Embeddings**: Each chunk is converted to vector embeddings using OpenAI
# - **Vector Store**: FAISS creates a searchable database of document embeddings
#
# ### 2. Question Answering
# - **Retrieval**: System finds most relevant document chunks for the question
# - **Generation**: OpenAI generates an answer based on retrieved context
# - **Prediction**: System produces its best answer to the question
#
# ### 3. Answer Evaluation
# - **Comparison**: AI answer is compared against the known correct answer
# - **Evaluation Chain**: LangChain evaluation determines if the AI answer is correct
# - **Grading**: System provides assessment of answer quality and accuracy
#
# ## Example Workflow
#
# 1. **Upload**: A document about company policies
# 2. **Question**: "What is the vacation policy for new employees?"
# 3. **Real Answer**: "New employees get 15 days of vacation after 6 months"
# 4. **AI Processing**: System retrieves relevant sections and generates answer
# 5. **Evaluation**: Compare AI answer vs real answer and grade accuracy
# 6. **Results**: Show question, real answer, AI answer, and evaluation grade
#
# ## Technical Details
#
# ### RAG Pipeline Architecture
# - **Document Loader**: Processes uploaded .txt files
# - **Text Splitter**: CharacterTextSplitter with 1000 character chunks
# - **Embeddings**: OpenAI embeddings for semantic search
# - **Vector Store**: FAISS for efficient similarity search
# - **Retriever**: Retrieval interface for finding relevant contexts
# - **QA Chain**: RetrievalQA with "stuff" chain type for answer generation
# - **Evaluation Chain**: QAEvalChain for automated answer grading
#
# ### Advanced Interface
# - **File Upload**: Drag-and-drop .txt document processing
# - **Conditional Fields**: Question and answer inputs enabled only after file upload
# - **Form Validation**: API key and input validation before processing
# - **Processing Indicator**: Spinner during RAG evaluation
# - **Results Display**: Structured output showing all evaluation components
#
# ### Most Complex Migration
#
# This represents the **most complex migration** of all 6 apps:
# - **6 LangChain packages**: Highest dependency count requiring specialized components
# - **Vector Database Integration**: FAISS for document embeddings and retrieval
# - **Multi-step Processing**: Document → Chunks → Embeddings → Vector Store → Retrieval → Generation → Evaluation
# - **Evaluation Chains**: Specialized chains for answer quality assessment
# - **Form-based Submission**: Complex conditional field enabling and validation
#
# ## Key Modernizations
#
# - **Python 3.13.3**: Latest Python version with performance improvements
# - **Poetry 2.1.4**: Modern dependency management with PEP 621 compliance
# - **Comprehensive LangChain**: 6 specialized packages for complete RAG functionality:
#   - `langchain-core`: Core functionality and base classes
#   - `langchain-text-splitters`: Document chunking utilities
#   - `langchain-community`: FAISS integration and embeddings
#   - `langchain-openai`: OpenAI model integration
#   - `langchain`: Complex chains (RetrievalQA, QAEvalChain)
#   - `faiss-cpu`: Vector database for similarity search
#   - `tiktoken`: Token counting for optimization
# - **Streamlit 1.49+**: Latest Streamlit features available
#
# ## Code Changes Summary
#
# Only **2 lines** of code changed from the original version:
# 1. Import: `from langchain.text_splitter import CharacterTextSplitter` → `from langchain_text_splitters import CharacterTextSplitter`
# 2. Chain method: `predictions = qachain.apply(real_qa)` → `predictions = qachain.batch(real_qa)`
#
# ## RAG Evaluation Categories
#
# The app evaluates these aspects:
#
# ### 1. Retrieval Quality
# - Does the system find the most relevant document sections?
# - Are the retrieved contexts sufficient to answer the question?
#
# ### 2. Generation Accuracy
# - Is the AI-generated answer factually correct?
# - Does it align with the information in the document?
#
# ### 3. Answer Completeness
# - Does the answer address all aspects of the question?
# - Is important information missing or hallucinated?
#
# ### 4. Evaluation Reliability
# - How accurately does the evaluation chain assess answer quality?
# - Are the evaluation criteria appropriate for the question type?
#
# ## Use Cases
#
# - **Content Quality Assurance**: Test RAG systems before production deployment
# - **Knowledge Base Validation**: Verify that document-based QA systems work correctly
# - **Hallucination Detection**: Identify when AI systems generate incorrect information
# - **RAG System Comparison**: Compare different retrieval and generation approaches
# - **Training Data Quality**: Assess whether knowledge bases support accurate answers
#
# ## Dependencies
#
# Comprehensive modern dependency stack with 6 LangChain packages:
# - `langchain>=0.3.0` - Complex chains and orchestration
# - `langchain-core>=0.3.0` - Fundamental LangChain components
# - `langchain-text-splitters>=0.3.0` - Document processing utilities
# - `langchain-community>=0.3.0` - FAISS and community integrations
# - `langchain-openai>=0.2.0` - OpenAI model integration
# - `faiss-cpu>=1.9.0` - Vector database for similarity search
# - `tiktoken>=0.8.0` - Token counting functionality
# - `streamlit>=1.49.0` - Modern web interface framework
#
# ## Migration Complexity Comparison
#
# | App | Lines Changed | LangChain Packages | Complexity |
# |-----|---------------|-------------------|------------|
# | Extract JSON | 3 | 2 | Simplest |
# | Blog generator | 3 | 2 | Simple |
# | Text redaction | 4 | 2 | Simple |
# | Text summarization | 3 | 4 | Medium |
# | Split & summarize | 4 | 5 | Complex |
# | **RAG Evaluation** | **2** | **6** | **Most Complex** |

# %% [markdown]
# # Update Notes: Streamlit Evaluate Q&A from Long Document App
# * Streamlit from 1.37.0 to 1.49+ (August 2025)
# * LangChain from 0.2.11 to 0.3+ (August 2025) - **Most complex migration**
# * Poetry from 1.8.2 to 2.1.4 (August 2025)
# * Python from 3.11.4 to 3.13.3 (April 2025)
# * FAISS from 1.8.0 to 1.9+ (August 2025)
# * Tiktoken from 0.7.0 to 0.8+ (August 2025)
# * ChromaDB 0.5.5 (removed - not needed with FAISS)

# %% [markdown]
# ## Objective
# Migrate the **most complex** Streamlit RAG evaluation app from older versions to the latest modern ones, maintaining identical functionality with **6 LangChain packages** (highest complexity) for comprehensive RAG evaluation workflow.

# %% [markdown]
# ## Version comparison
#
# | Component | Old Version | New Version | Main Change |
# |-----------|-------------|-------------|-------------|
# | Python | 3.11.4 | 3.13.3 | Performance improvements |
# | Poetry | 1.8.2 | 2.1.4 | PEP 621, package-mode |
# | Streamlit | 1.37.0 | 1.49+ | New features |
# | LangChain | 0.2.11 | **6 separate packages** | **Most complex architecture** |
# | LangChain-OpenAI | 0.1.19 | 0.2+ | Separate package |
# | LangChain-Community | 0.2.10 | 0.3+ | FAISS integration |
# | FAISS-CPU | 1.8.0 | 1.9+ | Vector database |
# | Tiktoken | 0.7.0 | 0.8+ | Token counting |
# | ChromaDB | 0.5.5 | **Removed** | Not needed with FAISS |

# %% [markdown]
# ## Configuration: pyproject.toml
#
# ### Old version (Poetry 1.x)
# ```toml
# [tool.poetry]
# name = "009-streamlit-evaluate-qanda-from-long-document"
# version = "0.1.0"
# description = ""
# authors = ["julio colomer <info@aiaccelera.com>"]
# readme = "README.md"
#
# [tool.poetry.dependencies]
# python = "3.11.4"
# streamlit = "^1.37.0"
# langchain = "^0.2.11"
# langchain-openai = "^0.1.19"
# chromadb = "^0.5.5"
# tiktoken = "^0.7.0"
# faiss-cpu = "^1.8.0.post1"
# langchain-community = "^0.2.10"
#
# [build-system]
# requires = ["poetry-core"]
# build-backend = "poetry.core.masonry.api"
# ```

# %% [markdown]
# ### New version (Poetry 2.x with PEP 621)
# ```toml
# [project]
# name = "streamlit-evaluate-qanda-from-long-document-modern"
# version = "0.2.0"
# description = "Modern version of streamlit RAG evaluation app with updated dependencies"
# authors = [
#     {name = "julio colomer", email = "info@aiaccelera.com"}
# ]
# readme = "README.md"
# requires-python = ">=3.13.3"
# dependencies = [
#     "streamlit>=1.49.0",
#     "langchain>=0.3.0",
#     "langchain-core>=0.3.0",
#     "langchain-text-splitters>=0.3.0",
#     "langchain-community>=0.3.0",
#     "langchain-openai>=0.2.0",
#     "faiss-cpu>=1.9.0",
#     "tiktoken>=0.8.0"
# ]
#
# [project.optional-dependencies]
# dev = [
#     "jupyter>=1.1.1",
#     "ipykernel>=6.29.0",
#     "black>=24.0.0",
#     "ruff>=0.8.0"
# ]
#
# [build-system]
# requires = ["poetry-core>=1.0.0"]
# build-backend = "poetry.core.masonry.api"
#
# [tool.poetry]
# package-mode = false
# ```

# %% [markdown]
# ## Key configuration changes
# 1. **`[project]` section**: Replaces `[tool.poetry]` (PEP 621 standard)
# 2. **`package-mode = false`**: Important for simple applications in Poetry 2.x
# 3. **Complex LangChain**: **6 separate packages** for complete RAG functionality
# 4. **ChromaDB removed**: Not needed since we're using FAISS for vector storage
# 5. **FAISS updated**: From 1.8.0 to 1.9+ for better vector database performance
# 6. **Optional dependencies**: Separated in `[project.optional-dependencies]`

# %% [markdown]
# ## Code changes: main.py
#
# Only **2 lines** change in the code (surprisingly clean for most complex app):

# %% [markdown]
# ### 1. Text splitter import
# ```python
# # Old version
# from langchain.text_splitter import CharacterTextSplitter
#
# # New version
# from langchain_text_splitters import CharacterTextSplitter
# ```

# %% [markdown]
# ### 2. Chain batch method
# ```python
# # Old version
# predictions = qachain.apply(real_qa)
#
# # New version
# predictions = qachain.batch(real_qa)
# ```

# %% [markdown]
# ### Imports that stay the same
# ```python
# # All these imports work identically in both versions
# from langchain_openai import OpenAI
# from langchain_community.embeddings import OpenAIEmbeddings
# from langchain_community.vectorstores import FAISS
# from langchain.chains import RetrievalQA
# from langchain.evaluation.qa import QAEvalChain
# ```

# %% [markdown]
# ## Why these changes - Complex LangChain RAG architecture
#
# This app requires **6 LangChain packages** for complete RAG evaluation:
#
# * **`langchain-core`**: Base classes and fundamental components
# * **`langchain-text-splitters`**: Document chunking (CharacterTextSplitter)
# * **`langchain-community`**: FAISS integration and OpenAI embeddings
# * **`langchain-openai`**: OpenAI model integration (LLM)
# * **`langchain`**: Complex chains (RetrievalQA, QAEvalChain)
# * **`faiss-cpu`**: Vector database for similarity search
# * **`tiktoken`**: Token counting for optimization
#
# **Benefits**: Specialized packages, optimal performance, comprehensive RAG functionality

# %% [markdown]
# ## App functionality - RAG Evaluation System
#
# This app implements a **complete RAG evaluation pipeline**:
#
# ### RAG Components
# 1. **Document Processing**: Upload → Text splitting → Embeddings
# 2. **Vector Storage**: FAISS database for similarity search
# 3. **Retrieval**: Find relevant document chunks for questions
# 4. **Generation**: AI generates answers based on retrieved context
# 5. **Evaluation**: Compare AI answers against known correct answers
#
# ### Interface elements
# * **Title**: "Evaluate a RAG App"
# * **Expandable info**: Explanation of RAG evaluation process
# * **File upload**: .txt document processing
# * **Question input**: Fact-checked questions (disabled until file uploaded)
# * **Answer input**: Known correct answers (disabled until file uploaded)
# * **Form submission**: API key validation and processing
# * **Results display**: Question, real answer, AI answer, evaluation grade

# %% [markdown]
# ## Complex workflow preservation
#
# The sophisticated RAG evaluation process is **exactly maintained**:
#
# ### Processing pipeline
# 1. **Document Upload**: User uploads .txt knowledge base file
# 2. **Text Chunking**: CharacterTextSplitter breaks document into 1000-char chunks
# 3. **Embedding Creation**: OpenAI embeddings for each chunk
# 4. **Vector Database**: FAISS stores embeddings for similarity search
# 5. **Retrieval Setup**: Create retriever interface for finding relevant chunks
# 6. **QA Chain**: RetrievalQA chain combines retrieval + generation
# 7. **Prediction Generation**: AI generates answer based on retrieved context
# 8. **Evaluation Chain**: QAEvalChain compares AI answer vs real answer
# 9. **Results Display**: Show all components with evaluation grade
#
# ### Form behavior
# * **Conditional enabling**: Question/answer fields only active after file upload
# * **API key validation**: Only proceed with valid sk- key
# * **Processing indicator**: Spinner during RAG evaluation
# * **State management**: Results persist across form submissions

# %% [markdown]
# ## Most complex migration comparison
#
# This is the **most complex migration** among all 6 apps:
#
# | App | Lines Changed | LangChain Packages | Vector DB | Complexity |
# |-----|---------------|-------------------|-----------|------------|
# | Extract JSON | 3 | 2 | No | Simplest |
# | Blog generator | 3 | 2 | No | Simple |
# | Text redaction | 4 | 2 | No | Simple |
# | Text summarization | 3 | 4 | No | Medium |
# | Split & summarize | 4 | 5 | No | Complex |
# | **RAG Evaluation** | **2** | **6** | **Yes** | **Most Complex** |
#
# ### Why it's most complex
# * **Highest dependency count**: 6 specialized LangChain packages
# * **Vector database**: FAISS integration for similarity search
# * **Multi-step pipeline**: Document → Chunks → Embeddings → Vector Store → Retrieval → Generation → Evaluation
# * **Evaluation chains**: Specialized chains for answer quality assessment
# * **File processing**: Document upload and text processing workflows
# * **Advanced UI**: Conditional field enabling and complex state management

# %% [markdown]
# ## Important issue: Poetry 2.x "package mode"
#
# Poetry 2.x by default expects your project to be an installable **Python package**. For simple applications like ours, this causes errors:
#
# ```
# The Poetry configuration is invalid:
#   - packages[0] : Unable to find package at <your-package-name>
# ```
#
# ### Solution
# Add `package-mode = false` in the `[tool.poetry]` section:
#
# ```toml
# [tool.poetry]
# package-mode = false
# ```

# %% [markdown]
# ## Migration steps
#
# #### 1. Create the new pyproject.toml
# ```bash
# # In the 009-streamlit-evaluate-QandA-from-long-document-v1-new/ folder
# # Create pyproject.toml with 6 LangChain packages + FAISS + tiktoken
# ```
#
# #### 2. Update main.py
# ```bash
# # Change the 2 lines mentioned above
# # Preserve exact RAG evaluation functionality
# ```
#
# #### 3. Install dependencies
# ```bash
# cd 009-streamlit-evaluate-QandA-from-long-document-v1-new
# poetry-2.1.4 install
# ```
#
# #### 4. Run the application
# ```bash
# poetry-2.1.4 run streamlit run main.py
# ```

# %% [markdown]
# ## Common problems and solutions
#
# #### Error: `ImportError: cannot import name 'CharacterTextSplitter' from 'langchain.text_splitter'`
# **Solution**: Change import to `from langchain_text_splitters import CharacterTextSplitter`
#
# #### Error: `AttributeError: 'RetrievalQA' object has no attribute 'apply'`
# **Solution**: Use `qachain.batch(real_qa)` instead of `qachain.apply(real_qa)`
#
# #### Error: `ImportError: cannot import name 'FAISS' from 'langchain_community.vectorstores'`
# **Solution**: Ensure `langchain-community>=0.3.0` is installed
#
# #### Error: `ModuleNotFoundError: No module named 'faiss'`
# **Solution**: Install `faiss-cpu>=1.9.0` (included in dependencies)
#
# #### File upload not working properly
# **Solution**: Verify Streamlit file upload API compatibility (should work identically)
#
# #### Error: `Unable to find package at <your-package-name>`
# **Solution**: Add `package-mode = false` in `[tool.poetry]`

# %% [markdown]
# ## Technical details preserved
#
# All RAG processing parameters remain **exactly the same**:
#
# * **Text splitter**: `CharacterTextSplitter(chunk_size=1000, chunk_overlap=0)`
# * **Embeddings**: OpenAI embeddings with API key
# * **Vector database**: FAISS with from_documents initialization
# * **Retrieval**: `db.as_retriever()` interface
# * **QA chain**: "stuff" chain type for document combination
# * **Evaluation**: QAEvalChain with question/answer/prediction keys
# * **LLM temperature**: Default OpenAI temperature settings
# * **File types**: .txt upload validation
# * **API key validation**: `startswith("sk-")` check
# * **Security**: `del openai_api_key` after use

# %% [markdown]
# ## RAG Evaluation Categories
#
# The app evaluates these critical aspects:
#
# ### 1. Retrieval Quality
# * **Document Chunking**: Are documents split appropriately for context?
# * **Embedding Quality**: Do embeddings capture semantic meaning effectively?
# * **Similarity Search**: Does FAISS find the most relevant chunks?
#
# ### 2. Generation Accuracy
# * **Context Usage**: Does AI use retrieved context appropriately?
# * **Answer Relevance**: Is the generated answer relevant to the question?
# * **Factual Correctness**: Does the answer align with document content?
#
# ### 3. Hallucination Detection
# * **Information Fabrication**: Does AI add information not in documents?
# * **Context Contradiction**: Does AI contradict the retrieved context?
# * **Confidence Assessment**: How confident is the AI in uncertain areas?
#
# ### 4. Overall System Performance
# * **Answer Quality**: How well does the complete pipeline perform?
# * **Consistency**: Does the system produce consistent results?
# * **Evaluation Accuracy**: How reliable is the evaluation chain itself?

# %% [markdown]
# ## Final result
#
# * **Functionality**: Identical RAG evaluation capabilities
# * **Interface**: Exactly the same upload, form, and evaluation UI
# * **Code changed**: 2 lines (surprisingly clean for most complex app)
# * **Dependencies**: 6 LangChain packages + FAISS + tiktoken (highest complexity)
# * **Benefits**: Modern dependencies, comprehensive RAG evaluation, optimal performance
# * **Migration time**: ~20 minutes (most complex but clean code changes)
# * **Unique features**: Complete RAG evaluation pipeline, vector database integration

# %% [markdown]
# ## Verification
# To confirm the migration works:
#
# ```bash
# cd 009-streamlit-evaluate-QandA-from-long-document-v1-new
# poetry-2.1.4 run python --version  # Should show 3.13.3
# poetry-2.1.4 run streamlit run main.py
# ```
#
# Test the RAG evaluation workflow:
# 1. Same "Evaluate a RAG App" interface
# 2. File upload functionality (.txt files)
# 3. Conditional question/answer input fields
# 4. Form submission with API key validation
# 5. Processing spinner during evaluation
# 6. Results display with all components:
#    - Question from input
#    - Real answer from input
#    - AI-generated answer from RAG system
#    - Evaluation grade (correct/incorrect assessment)
# 7. Same RAG evaluation quality and accuracy
# 8. Vector database performance (FAISS similarity search)
# 9. Document processing and embedding generation

# %% [markdown]
# ## Summary: Most Complex Migration Completed
#
# This migration represents the **pinnacle of complexity** in our series:
#
# * **6 LangChain packages**: Comprehensive modular architecture
# * **Vector database integration**: FAISS for semantic search
# * **Multi-step RAG pipeline**: Document → Embeddings → Retrieval → Generation → Evaluation
# * **Evaluation chains**: Automated answer quality assessment
# * **File processing workflows**: Upload and document handling
# * **Advanced UI patterns**: Conditional fields and state management
#
# Despite the complexity, only **2 lines of code changed**, demonstrating the robustness of LangChain's architecture and the effectiveness of modular dependency management.
